# %%
import cv2

# %%
image = cv2.imread(r"C:\Users\anubh\OneDrive\Downloads\testing_image.jpg")

# %%
if image is None:
    print("❌ Image not loaded. Check path.")
else:
    cv2.imshow("Window Title", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
image.shape
# Out:
# (350, 642, 3)

# %%
blurred_image = cv2.GaussianBlur(image, (7,7) , 2)



cv2.imshow("Window Title", blurred_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
